# %%
import numpy as np
import matplotlib.pyplot as plt
import pickle
import pdb

import session
reload(session)
# Out:
# <module 'session' from 'session.pyc'>

# %%
# set the main data directory (this needs to be changed by each user)
maindir = '/Volumes/Richardslab-Share/Colleen/AIBS_pilot_data/'

# %%
# get all the sessions to analyze
with open('mouse_df.pkl','r') as f:
    mdf = pickle.load(f)
    
allsessions = [str(sess) for sess in mdf['sessionid']]

# %%
# create a dictionary with Session objects prepared for analysis
sdict  = {}
nodata = []
for sess in allsessions:
    try:
        print("\nCreating session {}...".format(sess))
        sdict[sess] = session.Session(maindir,sess)    # creates a session object to work with
        sdict[sess].extract_info(load_run=False)                     # extracts necessary info for analysis
        print("finished session {}.".format(sess))
    except:
        nodata.append(sess)
        print("Could not find data for session {}".format(sess))
# Out:
# Creating session 712483302...
# Loading stimulus dictionary...
# WARNING: 534 dropped stimulus frames out of 243000.
# Loading alignment dataframe...
# NOTE: Stimulus alignment pickle already exists in /Volumes/Richardslab-Share/Colleen/AIBS_pilot_data/ophys_session_712483302
# Skipping running data...
# Loading ROI trace info...
# WARNING: During 1. sequence of bricks, the last blank segment of the 2. block was pushed to the start of the next sequence.
#
# WARNING: During last sequence of bricks, 2 segments (incl. blanks) from the 2. block were omitted.
#
# finished session 712483302.
#
# Creating session 712942208...
# Loading stimulus dictionary...
# WARNING: 254 dropped stimulus frames out of 243000.
# Loading alignment dataframe...
# NOTE: Stimulus alignment pickle already exists in /Volumes/Richardslab-Share/Colleen/AIBS_pilot_data/ophys_session_712942208
# Skipping running data...
# Loading ROI trace info...
# WARNING: During 1. sequence of bricks, the last blank segment of the 2. block was pushed to the start of the next sequence.
#
# WARNING: During last sequence of bricks, 2 segments (incl. blanks) from the 2. block were omitted.
#
# finished session 712942208.
#
# Creating session 715244457...
# Loading stimulus dictionary...
# Loading alignment dataframe...
# NOTE: Stimulus alignment pickle already exists in /Volumes/Richardslab-Share/Colleen/AIBS_pilot_data/ophys_session_715244457
# Skipping running data...
# Loading ROI trace info...
# WARNING: During 1. sequence of bricks, the last blank segment of the 2. block was pushed to the start of the next sequence.
#
# WARNING: During last sequence of bricks, 2 segments (incl. blanks) from the 2. block were omitted.
#
# finished session 715244457.
#
# Creating session 715576465...
# Could not find data for session 715576465
#
# Creating session 716425232...
# Loading stimulus dictionary...
# Loading alignment dataframe...
# NOTE: Stimulus alignment pickle already exists in /Volumes/Richardslab-Share/Colleen/AIBS_pilot_data/ophys_session_716425232
# Skipping running data...
# Loading ROI trace info...
# WARNING: During 1. sequence of bricks, the last blank segment of the 2. block was pushed to the start of the next sequence.
#
# WARNING: During last sequence of bricks, 2 segments (incl. blanks) from the 2. block were omitted.
#
# finished session 716425232.
#
# Creating session 716711420...
# Loading stimulus dictionary...
# Loading alignment dataframe...
# NOTE: Stimulus alignment pickle already exists in /Volumes/Richardslab-Share/Colleen/AIBS_pilot_data/ophys_session_716711420
# Skipping running data...
# Loading ROI trace info...
# WARNING: During 1. sequence of bricks, the last blank segment of the 2. block was pushed to the start of the next sequence.
#
# WARNING: During last sequence of bricks, 2 segments (incl. blanks) from the 2. block were omitted.
#
# finished session 716711420.
#
# Creating session 717030161...
# Loading stimulus dictionary...
# Loading alignment dataframe...
# NOTE: Stimulus alignment pickle already exists in /Volumes/Richardslab-Share/Colleen/AIBS_pilot_data/ophys_session_717030161
# Skipping running data...
# Loading ROI trace info...
# WARNING: During 1. sequence of bricks, the last blank segment of the 2. block was pushed to the start of the next sequence.
#
# WARNING: During last sequence of bricks, 2 segments (incl. blanks) from the 2. block were omitted.
#
# finished session 717030161.
#
# Creating session 717071321...
# Could not find data for session 717071321
#
# Creating session 718138179...
# Could not find data for session 718138179
#
# Creating session 718579351...
# Loading stimulus dictionary...
# Loading alignment dataframe...
# NOTE: Stimulus alignment pickle already exists in /Volumes/Richardslab-Share/Colleen/AIBS_pilot_data/ophys_session_718579351
# Skipping running data...
# Loading ROI trace info...
# WARNING: During 1. sequence of bricks, the last blank segment of the 2. block was pushed to the start of the next sequence.
#
# WARNING: During last sequence of bricks, 2 segments (incl. blanks) from the 2. block were omitted.
#
# finished session 718579351.
#
# Creating session 718742560...
# Loading stimulus dictionary...
# Loading alignment dataframe...
# NOTE: Stimulus alignment pickle already exists in /Volumes/Richardslab-Share/Colleen/AIBS_pilot_data/ophys_session_718742560
# Skipping running data...
# Loading ROI trace info...
# WARNING: During 1. sequence of bricks, the last blank segment of the 2. block was pushed to the start of the next sequence.
#
# WARNING: During last sequence of bricks, 2 segments (incl. blanks) from the 2. block were omitted.
#
# finished session 718742560.
#
# Creating session 718921993...
# Could not find data for session 718921993
#
# Creating session 719034388...
# Loading stimulus dictionary...
# Loading alignment dataframe...
# NOTE: Stimulus alignment pickle already exists in /Volumes/Richardslab-Share/Colleen/AIBS_pilot_data/ophys_session_719034388
# Skipping running data...
# Loading ROI trace info...
# WARNING: During 1. sequence of bricks, the last blank segment of the 2. block was pushed to the start of the next sequence.
#
# WARNING: During last sequence of bricks, 2 segments (incl. blanks) from the 2. block were omitted.
#
# finished session 719034388.
#
# Creating session 720115420...
# Could not find data for session 720115420
#
# Creating session 720247732...
# Could not find data for session 720247732
#
# Creating session 720519615...
# Loading stimulus dictionary...
# Loading alignment dataframe...
# NOTE: Stimulus alignment pickle already exists in /Volumes/Richardslab-Share/Colleen/AIBS_pilot_data/ophys_session_720519615
# Skipping running data...
# Loading ROI trace info...
# WARNING: 2 bricks blocks started instead of the expected 4.
#
# WARNING: During last sequence of bricks, the last blank segment of the 2. block was omitted.
#
# WARNING: 1 gabors blocks started instead of the expected 2.
#
# finished session 720519615.
#
# Creating session 720520553...
# Loading stimulus dictionary...
# Loading alignment dataframe...
# NOTE: Stimulus alignment pickle already exists in /Volumes/Richardslab-Share/Colleen/AIBS_pilot_data/ophys_session_720520553
# Skipping running data...
# Loading ROI trace info...
# WARNING: 2 bricks blocks started instead of the expected 4.
#
# WARNING: During last sequence of bricks, the last blank segment of the 2. block was omitted.
#
# WARNING: 1 gabors blocks started instead of the expected 2.
#
# finished session 720520553.
#
# Creating session 721032982...
# Loading stimulus dictionary...
# Loading alignment dataframe...
# NOTE: Stimulus alignment pickle already exists in /Volumes/Richardslab-Share/Colleen/AIBS_pilot_data/ophys_session_721032982
# Skipping running data...
# Loading ROI trace info...
# WARNING: 2 bricks blocks started instead of the expected 4.
#
# WARNING: During last sequence of bricks, the last blank segment of the 2. block was omitted.
#
# WARNING: 1 gabors blocks started instead of the expected 2.
#
# finished session 721032982.
#
# Creating session 721038464...
# Loading stimulus dictionary...
# Loading alignment dataframe...
# Could not find data for session 721038464
#
# Creating session 721975393...
# Loading stimulus dictionary...
# Loading alignment dataframe...
# NOTE: Stimulus alignment pickle already exists in /Volumes/Richardslab-Share/Colleen/AIBS_pilot_data/ophys_session_721975393
# Skipping running data...
# Loading ROI trace info...
# WARNING: 2 bricks blocks started instead of the expected 4.
#
# WARNING: During last sequence of bricks, the last blank segment of the 2. block was omitted.
#
# WARNING: 1 gabors blocks started instead of the expected 2.
#
# finished session 721975393.
#
# Creating session 722126561...
# Loading stimulus dictionary...
# Loading alignment dataframe...
# calculating stimulus alignment
# Creating the stim_df:
# ('stimtype:', 'b')
# ('stimtype:', 'g')
# Skipping running data...
# Loading ROI trace info...
# WARNING: 2 bricks blocks started instead of the expected 4.
#
# WARNING: During last sequence of bricks, the last blank segment of the 2. block was omitted.
#
# WARNING: 1 gabors blocks started instead of the expected 2.
#
# finished session 722126561.
#
# Creating session 722188453...
# Loading stimulus dictionary...
# Loading alignment dataframe...
# calculating stimulus alignment
# Creating the stim_df:
# ('stimtype:', 'b')
# ('stimtype:', 'g')
# Skipping running data...
# Loading ROI trace info...
# WARNING: During 1. sequence of bricks, the last blank segment of the 2. block was pushed to the start of the next sequence.
#
# WARNING: During last sequence of bricks, 2 segments (incl. blanks) from the 2. block were omitted.
# finished session 722188453.
#
# Creating session 723322122...
# Loading stimulus dictionary...
# Loading alignment dataframe...
# calculating stimulus alignment
# Creating the stim_df:
# ('stimtype:', 'b')
# ('stimtype:', 'g')
# Skipping running data...
# Loading ROI trace info...
# WARNING: 2 bricks blocks started instead of the expected 4.
#
# WARNING: During last sequence of bricks, the last blank segment of the 2. block was omitted.
#
# WARNING: 1 gabors blocks started instead of the expected 2.
#
# finished session 723322122.
#
# Creating session 723323411...
# Loading stimulus dictionary...
# Loading alignment dataframe...
# calculating stimulus alignment
# Creating the stim_df:
# ('stimtype:', 'b')
# ('stimtype:', 'g')
# Skipping running data...
# Loading ROI trace info...
# WARNING: 2 bricks blocks started instead of the expected 4.
#
# WARNING: During last sequence of bricks, the last blank segment of the 2. block was omitted.
#
# WARNING: 1 gabors blocks started instead of the expected 2.
#
# finished session 723323411.
#
# Creating session 724421207...
# Loading stimulus dictionary...
# Loading alignment dataframe...
# calculating stimulus alignment
# Creating the stim_df:
# ('stimtype:', 'b')
# ('stimtype:', 'g')
# Skipping running data...
# Loading ROI trace info...
# WARNING: 2 bricks blocks started instead of the expected 4.
#
# WARNING: During last sequence of bricks, the last blank segment of the 2. block was omitted.
#
# WARNING: 1 gabors blocks started instead of the expected 2.
#
# finished session 724421207.
#
# Creating session 724422062...
# Loading stimulus dictionary...
# Loading alignment dataframe...
# calculating stimulus alignment
# Creating the stim_df:
# ('stimtype:', 'b')
# ('stimtype:', 'g')
# Skipping running data...
# Loading ROI trace info...
# WARNING: 2 bricks blocks started instead of the expected 4.
#
# WARNING: During last sequence of bricks, the last blank segment of the 2. block was omitted.
#
# WARNING: 1 gabors blocks started instead of the expected 2.
#
# finished session 724422062.
#
# Creating session 725009252...
# Loading stimulus dictionary...
# Loading alignment dataframe...
# calculating stimulus alignment
# Creating the stim_df:
# ('stimtype:', 'b')
# ('stimtype:', 'g')
# Skipping running data...
# Loading ROI trace info...
# WARNING: 2 bricks blocks started instead of the expected 4.
#
# WARNING: During last sequence of bricks, the last blank segment of the 2. block was omitted.
#
# WARNING: 1 gabors blocks started instead of the expected 2.
#
# finished session 725009252.
#
# Creating session 725010342...
# Loading stimulus dictionary...
# Loading alignment dataframe...
# calculating stimulus alignment
# Creating the stim_df:
# ('stimtype:', 'b')
# ('stimtype:', 'g')
# Skipping running data...
# Loading ROI trace info...
# WARNING: 2 bricks blocks started instead of the expected 4.
#
# WARNING: During last sequence of bricks, the last blank segment of the 2. block was omitted.
#
# WARNING: 1 gabors blocks started instead of the expected 2.
#
# finished session 725010342.
#
# Creating session 726837871...
# Loading stimulus dictionary...
# Loading alignment dataframe...
# calculating stimulus alignment
# Creating the stim_df:
# ('stimtype:', 'b')
# ('stimtype:', 'g')
# Skipping running data...
# Loading ROI trace info...
# WARNING: 2 bricks blocks started instead of the expected 4.
#
# WARNING: During last sequence of bricks, the last blank segment of the 2. block was omitted.
#
# WARNING: 1 gabors blocks started instead of the expected 2.
#
# finished session 726837871.
#
# Creating session 726844248...
# Loading stimulus dictionary...
# Loading alignment dataframe...
# calculating stimulus alignment
# Creating the stim_df:
# ('stimtype:', 'b')
# ('stimtype:', 'g')
# Skipping running data...
# Loading ROI trace info...
# WARNING: 2 bricks blocks started instead of the expected 4.
#
# WARNING: During last sequence of bricks, the last blank segment of the 2. block was omitted.
#
# WARNING: 1 gabors blocks started instead of the expected 2.
#
# finished session 726844248.
#
# Creating session 727680211...
# Loading stimulus dictionary...
# Loading alignment dataframe...
# calculating stimulus alignment
# Creating the stim_df:
# ('stimtype:', 'b')
# ('stimtype:', 'g')
# Skipping running data...
# Loading ROI trace info...
# WARNING: 2 bricks blocks started instead of the expected 4.
#
# WARNING: During last sequence of bricks, the last blank segment of the 2. block was omitted.
#
# WARNING: 1 gabors blocks started instead of the expected 2.
#
# finished session 727680211.
#
# Creating session 727683236...
# Loading stimulus dictionary...
# Loading alignment dataframe...
# calculating stimulus alignment
# Creating the stim_df:
# ('stimtype:', 'b')
# ('stimtype:', 'g')
# Skipping running data...
# Loading ROI trace info...
# WARNING: 2 bricks blocks started instead of the expected 4.
#
# WARNING: During last sequence of bricks, the last blank segment of the 2. block was omitted.
#
# WARNING: 1 gabors blocks started instead of the expected 2.
#
# finished session 727683236.
#
# Creating session 714893802...
# Could not find data for session 714893802

# %%
# save the session dictionary in a pickle file
with open('session_data.pkl','w') as f:
    pickle.dump([maindir, mdf, allsessions, sdict, nodata], f)

# %%
# pick some padding
pad = (10,0)

# %%
# init traces lists
#traces = [[],[],[],[],[]]

# init dataframe indices lists
#mdfidx = [[],[],[],[],[]]

# error list
errs = []

# load the traces
print("Beginning to load traces...")
for index, row in mdf.iterrows():
    print(" - Loading traces for session {}...".format(row['sessionid']))
    S = allsessions[index]
    if index > 14 and not S in nodata:
        for i in range(5):
            print("     - Loading traces for {} images...".format(i))
            try:
                if i == 4:
                    segs = sdict[S].gabors.get_segs_by_criteria(by='seg', surp=1, gaborframe=3, stimPar2=16)
                else:
                    segs = sdict[S].gabors.get_segs_by_criteria(by='seg', surp=0, gaborframe=i, stimPar2=16)
                frames = sdict[S].gabors.get_2pframes_by_seg(segs)
                traces[i].append(sdict[S].get_roi_segments(frames,padding=pad))
                mdfidx[i].append(index)
            except:
                errs.append('S')
                print('            - Error when loading traces for session {}'.format(S))
                
print("finished.")
# Out:
# Beggining to load traces...
#  - Loading traces for session 712483302...
#  - Loading traces for session 712942208...
#  - Loading traces for session 715244457...
#  - Loading traces for session 715576465...
#  - Loading traces for session 716425232...
#  - Loading traces for session 716711420...
#  - Loading traces for session 717030161...
#  - Loading traces for session 717071321...
#  - Loading traces for session 718138179...
#  - Loading traces for session 718579351...
#  - Loading traces for session 718742560...
#  - Loading traces for session 718921993...
#  - Loading traces for session 719034388...
#  - Loading traces for session 720115420...
#  - Loading traces for session 720247732...
#  - Loading traces for session 720519615...
#      - Loading traces for 0 images...
#             - Error when loading traces for session 720519615
#      - Loading traces for 1 images...
#             - Error when loading traces for session 720519615
#      - Loading traces for 2 images...
#             - Error when loading traces for session 720519615
#      - Loading traces for 3 images...
#             - Error when loading traces for session 720519615
#      - Loading traces for 4 images...
#             - Error when loading traces for session 720519615
#  - Loading traces for session 720520553...
#      - Loading traces for 0 images...
#             - Error when loading traces for session 720520553
#      - Loading traces for 1 images...
#             - Error when loading traces for session 720520553
#      - Loading traces for 2 images...
#             - Error when loading traces for session 720520553
#      - Loading traces for 3 images...
#             - Error when loading traces for session 720520553
#      - Loading traces for 4 images...
#             - Error when loading traces for session 720520553
#  - Loading traces for session 721032982...
#      - Loading traces for 0 images...
#             - Error when loading traces for session 721032982
#      - Loading traces for 1 images...
#             - Error when loading traces for session 721032982
#      - Loading traces for 2 images...
#             - Error when loading traces for session 721032982
#      - Loading traces for 3 images...
#             - Error when loading traces for session 721032982
#      - Loading traces for 4 images...
#             - Error when loading traces for session 721032982
#  - Loading traces for session 721038464...
#  - Loading traces for session 721975393...
#      - Loading traces for 0 images...
#             - Error when loading traces for session 721975393
#      - Loading traces for 1 images...
#             - Error when loading traces for session 721975393
#      - Loading traces for 2 images...
#             - Error when loading traces for session 721975393
#      - Loading traces for 3 images...
#             - Error when loading traces for session 721975393
#      - Loading traces for 4 images...
#             - Error when loading traces for session 721975393
#  - Loading traces for session 722126561...
#      - Loading traces for 0 images...
#             - Error when loading traces for session 722126561
#      - Loading traces for 1 images...
#             - Error when loading traces for session 722126561
#      - Loading traces for 2 images...
#             - Error when loading traces for session 722126561
#      - Loading traces for 3 images...
#             - Error when loading traces for session 722126561
#      - Loading traces for 4 images...
#             - Error when loading traces for session 722126561
#  - Loading traces for session 722188453...
#      - Loading traces for 0 images...
#      - Loading traces for 1 images...
#      - Loading traces for 2 images...
#      - Loading traces for 3 images...
#      - Loading traces for 4 images...
#  - Loading traces for session 723322122...
#      - Loading traces for 0 images...
#             - Error when loading traces for session 723322122
#      - Loading traces for 1 images...
#             - Error when loading traces for session 723322122
#      - Loading traces for 2 images...
#             - Error when loading traces for session 723322122
#      - Loading traces for 3 images...
#             - Error when loading traces for session 723322122
#      - Loading traces for 4 images...
#             - Error when loading traces for session 723322122
#  - Loading traces for session 723323411...
#      - Loading traces for 0 images...
#             - Error when loading traces for session 723323411
#      - Loading traces for 1 images...
#             - Error when loading traces for session 723323411
#      - Loading traces for 2 images...
#             - Error when loading traces for session 723323411
#      - Loading traces for 3 images...
#             - Error when loading traces for session 723323411
#      - Loading traces for 4 images...
#             - Error when loading traces for session 723323411
#  - Loading traces for session 724421207...
#      - Loading traces for 0 images...
#      - Loading traces for 1 images...
#      - Loading traces for 2 images...
#      - Loading traces for 3 images...
#      - Loading traces for 4 images...
#  - Loading traces for session 724422062...
#      - Loading traces for 0 images...
#      - Loading traces for 1 images...
#      - Loading traces for 2 images...
#      - Loading traces for 3 images...
#      - Loading traces for 4 images...
#  - Loading traces for session 725009252...
#      - Loading traces for 0 images...
#      - Loading traces for 1 images...
#      - Loading traces for 2 images...
#      - Loading traces for 3 images...
#      - Loading traces for 4 images...
#  - Loading traces for session 725010342...
#      - Loading traces for 0 images...
#      - Loading traces for 1 images...
#      - Loading traces for 2 images...
#      - Loading traces for 3 images...
#      - Loading traces for 4 images...
#  - Loading traces for session 726837871...
#      - Loading traces for 0 images...
#      - Loading traces for 1 images...
#      - Loading traces for 2 images...
#      - Loading traces for 3 images...
#      - Loading traces for 4 images...
#  - Loading traces for session 726844248...
#      - Loading traces for 0 images...
#      - Loading traces for 1 images...
#      - Loading traces for 2 images...
#      - Loading traces for 3 images...
#      - Loading traces for 4 images...
#  - Loading traces for session 727680211...
#      - Loading traces for 0 images...
#      - Loading traces for 1 images...
#      - Loading traces for 2 images...
#      - Loading traces for 3 images...
#      - Loading traces for 4 images...
#  - Loading traces for session 727683236...
#      - Loading traces for 0 images...
#      - Loading traces for 1 images...
#      - Loading traces for 2 images...
#      - Loading traces for 3 images...
#      - Loading traces for 4 images...
#  - Loading traces for session 714893802...
# finished.

# %%
# save the traces in a pickle file
with open('trace_data_2.pkl','w') as f:
    pickle.dump([mdfidx,traces], f)

# %%
# get dF over F
dftraces = [[],[],[],[],[]]
for i in range(5):
    for j, trace in enumerate(traces[i]):
        df0 = np.tile(np.nanmean(trace[:,:pad[0],:],axis=1,keepdims=True),(1,trace.shape[1],1))
        dftraces[i].append((trace - df0)/df0)
#plt.plot(np.nanmean(dftrace,axis=0))
#plt.show()

# %%
mdfidx[0]
# Out:
# [0, 1, 2, 4, 5, 6, 9, 10, 12, 21, 24, 25, 26, 27, 28, 29, 30, 31]

# %%
mdf
# Out:
#     sessionid  mouseid  depth  sess_n  within_sess_n  overall_sess_n  \
# 0   712483302        2     20       3              1               3
# 1   712942208        2    375       4              1               6
# 2   715244457        2     20       3              3               5
# 3   715576465        4     20       2              1               2
# 4   716425232        2    375       4              2               7
# 5   716711420        2     20       1              1               1
# 6   717030161        2    375       2              1               2
# 7   717071321        4    375       3              1               5
# 8   718138179        4     20       2              2               3
# 9   718579351        4    375       3              2               6
# 10  718742560        4     20       2              3               4
# 11  718921993        1    175       5              1               6
# 12  719034388        4    375       1              1               1
# 13  720115420        1     75       4              1               4
# 14  720247732        4     20       4              1               7
# 15  720519615        1    175       5              2               7
# 16  720520553        1     75       4              2               5
# 17  721032982        1    175       3              1               3
# 18  721038464        1     75       6              1               8
# 19  721975393        1    175       2              1               2
# 20  722126561        1     75       7              1               9
# 21  722188453        4     20       4              2               8
# 22  723322122        1    175       1              1               1
# 23  723323411        1     75       8              1              10
# 24  724421207        3    175       3              1               3
# 25  724422062        3     75       4              1               4
# 26  725009252        3    175       2              1               2
# 27  725010342        3     75       5              1               5
# 28  726837871        3    175       7              1               7
# 29  726844248        3     75       6              1               6
# 30  727680211        3    175       1              1               1
# 31  727683236        3     75       8              1               8
# 32  714893802        2     20       3              2               4
#
#    pass_fail  all_files  any_files
# 0          F          1          1
# 1          F          1          1
# 2          P          1          1
# 3          F          0          1
# 4          P          1          1
# 5          P          1          1
# 6          P          1          1
# 7          F          0          1
# 8          F          0          1
# 9          P          1          1
# 10         F          1          1
# 11         F          0          1
# 12         P          1          1
# 13         F          0          1
# 14         F          0          1
# 15         P          1          1
# 16         P          1          1
# 17         P          1          1
# 18         P          1          1
# 19         P          1          1
# 20         P          1          1
# 21         P          1          1
# 22         P          1          1
# 23         P          1          1
# 24         P          1          1
# 25         P          1          1
# 26         P          1          1
# 27         P          1          1
# 28         P          1          1
# 29         P          1          1
# 30         P          1          1
# 31         P          1          1
# 32         F          0          0

# %%
# initialize some arrays
resp = [np.zeros((22,4,8,4))+np.nan,
        np.zeros((22,4,8,4))+np.nan,
        np.zeros((22,4,8,4))+np.nan,
        np.zeros((22,4,8,4))+np.nan,
        np.zeros((22,4,8,4))+np.nan] # list over images (A-E), then time, quarter, session, mouse


# calculate the mean first, second, third and quarter response for each mouse/session
for i in range(5):
    for j, trace in enumerate(dftraces[i]):
        
        # determine the mouse and session number
        m = mdf.iloc[mdfidx[i][j]]['mouseid']-1
        s = mdf.iloc[mdfidx[i][j]]['sess_n']-1
    
        # determine whether the session passed
        if mdf.iloc[mdfidx[i][j]]['pass_fail'] == 'F':
            print("No usable data for image {}, index {}, mouse {} session {}".format(i+1,mdfidx[i][j],m+1,s+1))
            continue
    
        # determine the number of segments in each bin
        nsegs = trace.shape[2]
        ndiv  = int(np.floor(nsegs/4))
    
        # store each segment
        resp[i][:trace.shape[1],0,s,m] = np.nanmean(np.nanmean(trace[:,:,:ndiv],axis=2),axis=0)
        resp[i][:trace.shape[1],1,s,m] = np.nanmean(np.nanmean(trace[:,:,ndiv+1:ndiv*2],axis=2),axis=0)
        resp[i][:trace.shape[1],2,s,m] = np.nanmean(np.nanmean(trace[:,:,ndiv*2+1:ndiv*3],axis=2),axis=0)
        resp[i][:trace.shape[1],3,s,m] = np.nanmean(np.nanmean(trace[:,:,ndiv*3+1:],axis=2),axis=0)
# Out:
# No usable data for image 1, index 0, mouse 2 session 3
# No usable data for image 1, index 1, mouse 2 session 4
# No usable data for image 1, index 10, mouse 4 session 2
# No usable data for image 2, index 0, mouse 2 session 3
# No usable data for image 2, index 1, mouse 2 session 4
# No usable data for image 2, index 10, mouse 4 session 2
# No usable data for image 3, index 0, mouse 2 session 3
# No usable data for image 3, index 1, mouse 2 session 4
# No usable data for image 3, index 10, mouse 4 session 2
# No usable data for image 4, index 0, mouse 2 session 3
# No usable data for image 4, index 1, mouse 2 session 4
# No usable data for image 4, index 10, mouse 4 session 2
# No usable data for image 5, index 0, mouse 2 session 3
# No usable data for image 5, index 1, mouse 2 session 4
# No usable data for image 5, index 10, mouse 4 session 2

# %%
# create a time variable for plotting
fps = 30.0
spf = 1.0/fps
t   = np.arange(-pad[0]*spf,9*spf,spf)
nt  = t.shape[0]

# %%
# plot the responses for animal 2, session 1 (layer 1)
images = ['A','B','C','D','E']
m = 1
ylims = [-0.75,0.75]
fig, axes = plt.subplots(2,3,sharey=False)
for s in range(2):
    for i in range(5):
        if s < 1 and i < 3:
            axes[s,i].plot(t,resp[i][:nt,:,s,m]*100)
            axes[s,i].plot(t,np.zeros((nt,)),'k:')
            axes[s,i].plot([0,0],[-5,5],'k--')
            axes[s,i].set_title(images[i])
            axes[s,i].set_ylim([ylims[0],ylims[1]])
            if i > 0:
                axes[s,i].axis('off')
            else:
                axes[s,i].set_ylabel('dF/F (%)')
                axes[s,i].set_xlabel('Time (s)')
                axes[s,i].spines["top"].set_visible(False)
                axes[s,i].spines["bottom"].set_visible(False)
                axes[s,i].spines["right"].set_visible(False)
                axes[s,i].spines["left"].set_visible(False)
        if s == 1 and i == 0:
            axes[s,i].plot(t,resp[0][:nt,:,0,m])
            axes[s,i].legend(['1st Q','2nd Q','3rd Q','4th Q'],loc='center',mode='expand',framealpha=1.0)
            axes[s,i].set_ylim([-1,1])
            axes[s,i].axis('off')
        elif s == 1 and i > 2:
            axes[s,i-2].plot(t,resp[i][:nt,:,s-1,m]*100)
            axes[s,i-2].plot(t,np.zeros((nt,)),'k:')
            axes[s,i-2].plot([0,0],[-5,5],'k--')
            axes[s,i-2].set_ylim([ylims[0],ylims[1]])
            axes[s,i-2].set_title(images[i])
            axes[s,i-2].axis('off')
plt.suptitle("Mouse 2 (Rbp4) - session 1 - 20 microns depth")
plt.show()

# %%
# plot the responses for animal 2, session 2 (layer 5)
images = ['A','B','C','D','E']
m = 1
ylims = [-1.5,1.5]
fig, axes = plt.subplots(2,3,sharey=False)
for s in range(2):
    for i in range(5):
        if s < 1 and i < 3:
            axes[s,i].plot(t,resp[i][:nt,:,s+1,m]*100)
            axes[s,i].plot(t,np.zeros((nt,)),'k:')
            axes[s,i].plot([0,0],[-5,5],'k--')
            axes[s,i].set_title(images[i])
            axes[s,i].set_ylim([ylims[0],ylims[1]])
            if i > 0:
                axes[s,i].axis('off')
            else:
                axes[s,i].set_ylabel('dF/F (%)')
                axes[s,i].set_xlabel('Time (s)')
                axes[s,i].spines["top"].set_visible(False)
                axes[s,i].spines["bottom"].set_visible(False)
                axes[s,i].spines["right"].set_visible(False)
                axes[s,i].spines["left"].set_visible(False)
        if s == 1 and i == 0:
            axes[s,i].plot(t,resp[0][:nt,:,0,m])
            axes[s,i].legend(['1st Q','2nd Q','3rd Q','4th Q'],loc='center',mode='expand',framealpha=1.0)
            axes[s,i].set_ylim([-1,1])
            axes[s,i].axis('off')
        elif s == 1 and i > 2:
            axes[s,i-2].plot(t,resp[i][:nt,:,s,m]*100)
            axes[s,i-2].plot(t,np.zeros((nt,)),'k:')
            axes[s,i-2].plot([0,0],[-5,5],'k--')
            axes[s,i-2].set_ylim([ylims[0],ylims[1]])
            axes[s,i-2].set_title(images[i])
            axes[s,i-2].axis('off')
plt.suptitle("Mouse 2 (Rbp4) - session 2 - 375 microns depth")
plt.show()

# %%
# plot the responses for animal 2, session 3 (layer 1)
images = ['A','B','C','D','E']
m = 1
ylims = [-0.75,0.75]
fig, axes = plt.subplots(2,3,sharey=False)
for s in range(2):
    for i in range(5):
        if s < 1 and i < 3:
            axes[s,i].plot(t,resp[i][:nt,:,s+2,m]*100)
            axes[s,i].plot(t,np.zeros((nt,)),'k:')
            axes[s,i].plot([0,0],[-5,5],'k--')
            axes[s,i].set_title(images[i])
            axes[s,i].set_ylim([ylims[0],ylims[1]])
            if i > 0:
                axes[s,i].axis('off')
            else:
                axes[s,i].set_ylabel('dF/F (%)')
                axes[s,i].set_xlabel('Time (s)')
                axes[s,i].spines["top"].set_visible(False)
                axes[s,i].spines["bottom"].set_visible(False)
                axes[s,i].spines["right"].set_visible(False)
                axes[s,i].spines["left"].set_visible(False)
        if s == 1 and i == 0:
            axes[s,i].plot(t,resp[0][:nt,:,0,m])
            axes[s,i].legend(['1st Q','2nd Q','3rd Q','4th Q'],loc='center',mode='expand',framealpha=1.0)
            axes[s,i].set_ylim([-1,1])
            axes[s,i].axis('off')
        elif s == 1 and i > 2:
            axes[s,i-2].plot(t,resp[i][:nt,:,s+1,m]*100)
            axes[s,i-2].plot(t,np.zeros((nt,)),'k:')
            axes[s,i-2].plot([0,0],[-5,5],'k--')
            axes[s,i-2].set_ylim([ylims[0],ylims[1]])
            axes[s,i-2].set_title(images[i])
            axes[s,i-2].axis('off')
plt.suptitle("Mouse 2 (Rbp4) - session 3 - 20 microns depth")
plt.show()

# %%
# plot the responses for animal 2, session 4 (layer 5)
images = ['A','B','C','D','E']
m = 1
ylims = [-1.5,1.5]
fig, axes = plt.subplots(2,3,sharey=False)
for s in range(2):
    for i in range(5):
        if s < 1 and i < 3:
            axes[s,i].plot(t,resp[i][:nt,:,s+3,m]*100)
            axes[s,i].plot(t,np.zeros((nt,)),'k:')
            axes[s,i].plot([0,0],[-5,5],'k--')
            axes[s,i].set_title(images[i])
            axes[s,i].set_ylim([ylims[0],ylims[1]])
            if i > 0:
                axes[s,i].axis('off')
            else:
                axes[s,i].set_ylabel('dF/F (%)')
                axes[s,i].set_xlabel('Time (s)')
                axes[s,i].spines["top"].set_visible(False)
                axes[s,i].spines["bottom"].set_visible(False)
                axes[s,i].spines["right"].set_visible(False)
                axes[s,i].spines["left"].set_visible(False)
        if s == 1 and i == 0:
            axes[s,i].plot(t,resp[0][:nt,:,0,m])
            axes[s,i].legend(['1st Q','2nd Q','3rd Q','4th Q'],loc='center',mode='expand',framealpha=1.0)
            axes[s,i].set_ylim([-1,1])
            axes[s,i].axis('off')
        elif s == 1 and i > 2:
            axes[s,i-2].plot(t,resp[i][:nt,:,s+2,m]*100)
            axes[s,i-2].plot(t,np.zeros((nt,)),'k:')
            axes[s,i-2].plot([0,0],[-5,5],'k--')
            axes[s,i-2].set_ylim([ylims[0],ylims[1]])
            axes[s,i-2].set_title(images[i])
            axes[s,i-2].axis('off')
plt.suptitle("Mouse 2 (Rbp4) - session 4 - 375 microns depth")
plt.show()

# %%
# plot the responses for animal 3, session 1 (layer 2/3)
images = ['A','B','C','D','E']
m = 2
ylims = [-4,4]
fig, axes = plt.subplots(2,3,sharey=False)
for s in range(2):
    for i in range(5):
        if s < 1 and i < 3:
            axes[s,i].plot(t,resp[i][:nt,:,s,m]*100)
            axes[s,i].plot(t,np.zeros((nt,)),'k:')
            axes[s,i].plot([0,0],[-5,5],'k--')
            axes[s,i].set_title(images[i])
            axes[s,i].set_ylim([ylims[0],ylims[1]])
            if i > 0:
                axes[s,i].axis('off')
            else:
                axes[s,i].set_ylabel('dF/F (%)')
                axes[s,i].set_xlabel('Time (s)')
                axes[s,i].spines["top"].set_visible(False)
                axes[s,i].spines["bottom"].set_visible(False)
                axes[s,i].spines["right"].set_visible(False)
                axes[s,i].spines["left"].set_visible(False)
        if s == 1 and i == 0:
            axes[s,i].plot(t,resp[0][:nt,:,0,m])
            axes[s,i].legend(['1st Q','2nd Q','3rd Q','4th Q'],loc='center',mode='expand',framealpha=1.0)
            axes[s,i].set_ylim([-1,1])
            axes[s,i].axis('off')
        elif s == 1 and i > 2:
            axes[s,i-2].plot(t,resp[i][:nt,:,s-1,m]*100)
            axes[s,i-2].plot(t,np.zeros((nt,)),'k:')
            axes[s,i-2].plot([0,0],[-5,5],'k--')
            axes[s,i-2].set_ylim([ylims[0],ylims[1]])
            axes[s,i-2].set_title(images[i])
            axes[s,i-2].axis('off')
plt.suptitle("Mouse 3 (Cux2) - session 1 - 175 microns depth")
plt.show()

# %%
# plot the responses for animal 3, session 2 (layer 2/3)
images = ['A','B','C','D','E']
m = 2
ylims = [-1.5,1.5]
fig, axes = plt.subplots(2,3,sharey=False)
for s in range(2):
    for i in range(5):
        if s < 1 and i < 3:
            axes[s,i].plot(t,resp[i][:nt,:,s+1,m]*100)
            axes[s,i].plot(t,np.zeros((nt,)),'k:')
            axes[s,i].plot([0,0],[-5,5],'k--')
            axes[s,i].set_title(images[i])
            axes[s,i].set_ylim([ylims[0],ylims[1]])
            if i > 0:
                axes[s,i].axis('off')
            else:
                axes[s,i].set_ylabel('dF/F (%)')
                axes[s,i].set_xlabel('Time (s)')
                axes[s,i].spines["top"].set_visible(False)
                axes[s,i].spines["bottom"].set_visible(False)
                axes[s,i].spines["right"].set_visible(False)
                axes[s,i].spines["left"].set_visible(False)
        if s == 1 and i == 0:
            axes[s,i].plot(t,resp[0][:nt,:,0,m])
            axes[s,i].legend(['1st Q','2nd Q','3rd Q','4th Q'],loc='center',mode='expand',framealpha=1.0)
            axes[s,i].set_ylim([-1,1])
            axes[s,i].axis('off')
        elif s == 1 and i > 2:
            axes[s,i-2].plot(t,resp[i][:nt,:,s,m]*100)
            axes[s,i-2].plot(t,np.zeros((nt,)),'k:')
            axes[s,i-2].plot([0,0],[-5,5],'k--')
            axes[s,i-2].set_ylim([ylims[0],ylims[1]])
            axes[s,i-2].set_title(images[i])
            axes[s,i-2].axis('off')
plt.suptitle("Mouse 3 (Cux2) - session 2 - 175 microns depth")
plt.show()

# %%
# plot the responses for animal 3, session 3 (layer 2/3)
images = ['A','B','C','D','E']
m = 2
ylims = [-2,2]
fig, axes = plt.subplots(2,3,sharey=False)
for s in range(2):
    for i in range(5):
        if s < 1 and i < 3:
            axes[s,i].plot(t,resp[i][:nt,:,s+2,m]*100)
            axes[s,i].plot(t,np.zeros((nt,)),'k:')
            axes[s,i].plot([0,0],[-5,5],'k--')
            axes[s,i].set_title(images[i])
            axes[s,i].set_ylim([ylims[0],ylims[1]])
            if i > 0:
                axes[s,i].axis('off')
            else:
                axes[s,i].set_ylabel('dF/F (%)')
                axes[s,i].set_xlabel('Time (s)')
                axes[s,i].spines["top"].set_visible(False)
                axes[s,i].spines["bottom"].set_visible(False)
                axes[s,i].spines["right"].set_visible(False)
                axes[s,i].spines["left"].set_visible(False)
        if s == 1 and i == 0:
            axes[s,i].plot(t,resp[0][:nt,:,0,m])
            axes[s,i].legend(['1st Q','2nd Q','3rd Q','4th Q'],loc='center',mode='expand',framealpha=1.0)
            axes[s,i].set_ylim([-1,1])
            axes[s,i].axis('off')
        elif s == 1 and i > 2:
            axes[s,i-2].plot(t,resp[i][:nt,:,s+1,m]*100)
            axes[s,i-2].plot(t,np.zeros((nt,)),'k:')
            axes[s,i-2].plot([0,0],[-5,5],'k--')
            axes[s,i-2].set_ylim([ylims[0],ylims[1]])
            axes[s,i-2].set_title(images[i])
            axes[s,i-2].axis('off')
plt.suptitle("Mouse 3 (Cux2) - session 3 - 175 microns depth")
plt.show()

# %%
# plot the responses for animal 3, session 4 (layer 1)
images = ['A','B','C','D','E']
m = 2
ylims = [-1.5,1.5]
fig, axes = plt.subplots(2,3,sharey=False)
for s in range(2):
    for i in range(5):
        if s < 1 and i < 3:
            axes[s,i].plot(t,resp[i][:nt,:,s+3,m]*100)
            axes[s,i].plot(t,np.zeros((nt,)),'k:')
            axes[s,i].plot([0,0],[-5,5],'k--')
            axes[s,i].set_title(images[i])
            axes[s,i].set_ylim([ylims[0],ylims[1]])
            if i > 0:
                axes[s,i].axis('off')
            else:
                axes[s,i].set_ylabel('dF/F (%)')
                axes[s,i].set_xlabel('Time (s)')
                axes[s,i].spines["top"].set_visible(False)
                axes[s,i].spines["bottom"].set_visible(False)
                axes[s,i].spines["right"].set_visible(False)
                axes[s,i].spines["left"].set_visible(False)
        if s == 1 and i == 0:
            axes[s,i].plot(t,resp[0][:nt,:,0,m])
            axes[s,i].legend(['1st Q','2nd Q','3rd Q','4th Q'],loc='center',mode='expand',framealpha=1.0)
            axes[s,i].set_ylim([-1,1])
            axes[s,i].axis('off')
        elif s == 1 and i > 2:
            axes[s,i-2].plot(t,resp[i][:nt,:,s+2,m]*100)
            axes[s,i-2].plot(t,np.zeros((nt,)),'k:')
            axes[s,i-2].plot([0,0],[-5,5],'k--')
            axes[s,i-2].set_ylim([ylims[0],ylims[1]])
            axes[s,i-2].set_title(images[i])
            axes[s,i-2].axis('off')
plt.suptitle("Mouse 3 (Cux2) - session 4 - 75 microns depth")
plt.show()

# %%
# plot the responses for animal 4, session 4 (layer 1)
images = ['A','B','C','D','E']
m = 3
ylims = [-2,2]
fig, axes = plt.subplots(2,3,sharey=False)
for s in range(2):
    for i in range(5):
        if s < 1 and i < 3:
            axes[s,i].plot(t,resp[i][:nt,:,s+3,m]*100)
            axes[s,i].plot(t,np.zeros((nt,)),'k:')
            axes[s,i].plot([0,0],[-5,5],'k--')
            axes[s,i].set_title(images[i])
            axes[s,i].set_ylim([ylims[0],ylims[1]])
            if i > 0:
                axes[s,i].axis('off')
            else:
                axes[s,i].set_ylabel('dF/F (%)')
                axes[s,i].set_xlabel('Time (s)')
                axes[s,i].spines["top"].set_visible(False)
                axes[s,i].spines["bottom"].set_visible(False)
                axes[s,i].spines["right"].set_visible(False)
                axes[s,i].spines["left"].set_visible(False)
        if s == 1 and i == 0:
            axes[s,i].plot(t,resp[0][:nt,:,0,m])
            axes[s,i].legend(['1st Q','2nd Q','3rd Q','4th Q'],loc='center',mode='expand',framealpha=1.0)
            axes[s,i].set_ylim([-1,1])
            axes[s,i].axis('off')
        elif s == 1 and i > 2:
            axes[s,i-2].plot(t,resp[i][:nt,:,s+2,m]*100)
            axes[s,i-2].plot(t,np.zeros((nt,)),'k:')
            axes[s,i-2].plot([0,0],[-5,5],'k--')
            axes[s,i-2].set_ylim([ylims[0],ylims[1]])
            axes[s,i-2].set_title(images[i])
            axes[s,i-2].axis('off')
plt.suptitle("Mouse 4 (Rbp4) - session 4 - 20 microns depth")
plt.show()
